# %% [markdown]
# <a href="https://colab.research.google.com/github/96harsh52/Predict_loan_amount/blob/main/Predict_loan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Using the data in Excel file Loans, construct a scat-ter chart for monthly income versus loan amount and add a linear trendline. What is the regression model? If an individual has 7336 as monthly income, what would you predict the loan amount to be?

# %%
import numpy as np
import math as mt
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 8.0)
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
data=pd.read_excel("/home/dai/Downloads/Data_Files-20191003T101052Z-001/Data_Files/Loans.xlsx")
data
# Out:
#     Monthly_Income  Ln_Orig  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0             4246   148000         NaN         NaN         NaN         NaN
# 1             3200   168701         NaN         NaN         NaN         NaN
# 2             4150   111000         NaN         NaN         NaN         NaN
# 3             2957   115500         NaN         NaN         NaN         NaN
# 4             6270    96000         NaN         NaN         NaN         NaN
# ..             ...      ...         ...         ...         ...         ...
# 62            4800   163400         NaN         NaN         NaN         NaN
# 63            5025   272870         NaN         NaN         NaN         NaN
# 64            4117   322000         NaN         NaN         NaN         NaN
# 65            3867    95410         NaN         NaN         NaN         NaN
# 66            7336   101500         NaN         NaN         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7
# 0         NaN         NaN
# ...

# %%
X = data['Monthly_Income'].values
Y = data['Ln_Orig'].values

mean_x = np.mean(X)
mean_y = np.mean(Y)
n = len(X)
max_x = np.max(X) 
min_x = np.min(X)  
numer = 0
denom = 0
for i in range(n):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
slope = numer / denom
intercept = mean_y - (slope * mean_x)

x = np.linspace(min_x, max_x, 10)
y = slope * x + intercept
plt.plot(x, y, color= 'r', label='Regression Line')


X = X.reshape((n, 1))
reg = LinearRegression()
reg = reg.fit(X, Y)

    
plt.scatter(X, Y, color= 'g', label='Regression Line')
plt.xlabel('Monthly_Income')
plt.ylabel('Ln_Orig')


y = slope * 7336 + intercept
print(y)
# Out:
# 104963.8436926112

# %% [markdown]
# Using the results of fitting the Home Market Value regression line, compute the errors associated with each observation using formula (8.3) and construct a histogram.

# %%
data1=pd.read_excel("/home/dai/Downloads/Data_Files-20191003T101052Z-001/Data_Files/Home Market Value.xlsx",header=2)
data1
# Out:
#     House Age  Square Feet  Market Value
# 0          33         1812         90000
# 1          32         1914        104400
# 2          32         1842         93300
# 3          33         1812         91000
# 4          32         1836        101900
# 5          33         2028        108500
# 6          32         1732         87600
# 7          33         1850         96000
# 8          32         1791         89200
# 9          33         1666         88400
# 10         32         1852        100800
# 11         32         1620         96700
# 12         32         1692         87500
# 13         32         2372        114000
# 14         32         2372        113200
# 15         33         1666         87500
# 16         32         2123        116100
# 17         32         1620         94700
# 18         32         1731         86400
# 19         32         1666         87100
# 20         28         1520         83400
# 21         27         1484         79800
# ...

# %%
Y = data1['Market Value'].values
X = data1['Square Feet'].values

mean_x = np.mean(X)
mean_y = np.mean(Y)
n = len(X)
max_x = np.max(X) 
min_x = np.min(X)  
numer = 0
denom = 0
for i in range(n):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
slope = numer / denom
intercept = mean_y - (slope * mean_x)

x = np.linspace(min_x, max_x, 10)
y = slope * x + intercept
plt.plot(x, y, color= 'r', label='Regression Line')


X = X.reshape((n, 1))
reg = LinearRegression()
reg = reg.fit(X, Y)

    
plt.scatter(X, Y, color= 'g', label='Regression Line')
plt.xlabel('square Feet')
plt.ylabel('Market value')
# Out:
# Text(0, 0.5, 'Market value')

# %%
#  4
Y1 = slope * X + intercept
y2=y-Y1
print(y2)
# Out:
# [ 84106.61484978  87625.82382928  91145.03280877  94664.24178827
#   98183.45076776 101702.65974726 105221.86872675 108741.07770625
#  112260.28668574 115779.49566524]
# [[-1.20525122e+04 -8.53330319e+03 -5.01409421e+03 -1.49488523e+03
#    2.02432375e+03  5.54353273e+03  9.06274171e+03  1.25819507e+04
#    1.61011597e+04  1.96203686e+04]
#  [-1.56262222e+04 -1.21070132e+04 -8.58780421e+03 -5.06859523e+03
#   -1.54938625e+03  1.96982273e+03  5.48903170e+03  9.00824068e+03
#    1.25274497e+04  1.60466586e+04]
#  [-1.31036033e+04 -9.58439437e+03 -6.06518539e+03 -2.54597641e+03
#    9.73232572e+02  4.49244155e+03  8.01165053e+03  1.15308595e+04
#    1.50500685e+04  1.85692775e+04]
#  [-1.20525122e+04 -8.53330319e+03 -5.01409421e+03 -1.49488523e+03
#    2.02432375e+03  5.54353273e+03  9.06274171e+03  1.25819507e+04
#    1.61011597e+04  1.96203686e+04]
#  [-1.28933851e+04 -9.37417613e+03 -5.85496715e+03 -2.33575817e+03
#    1.18345081e+03  4.70265979e+03  8.22186877e+03  1.17410777e+04
# ...

# %% [markdown]
# moving avg

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

data2=pd.read_excel("/home/dai/Downloads/Data_Files-20191003T101052Z-001/Data_Files/New Car Sales.xlsx",header=2)
data2
# Out:
#     Year Month  Units
# 0      1   Jan  39810
# 1      1   Feb  40081
# 2      1   Mar  47440
# 3      1   Apr  47297
# 4      1   May  49211
# 5      1   Jun  51479
# 6      1   Jul  46466
# 7      1   Aug  45208
# 8      1   Sep  44800
# 9      1   Oct  46989
# 10     1   Nov  42161
# 11     1   Dec  44186
# 12     2   Jan  42227
# 13     2   Feb  45422
# 14     2   Mar  54075
# 15     2   Apr  50926
# 16     2   May  53572
# 17     2   Jun  54920
# 18     2   Jul  54449
# 19     2   Aug  56079
# 20     2   Sep  52177
# 21     2   Oct  50087
# 22     2   Nov  48513
# 23     2   Dec  49278
# 24     3   Jan  48134
# 25     3   Feb  54887
# 26     3   Mar  61064
# 27     3   Apr  53350
# 28     3   May  59467
# 29     3   Jun  59370
# 30     3   Jul  55088
# 31     3   Aug  59349
# 32     3   Sep  54472
# 33     3   Oct  53164
# 34     3   Nov  48793
# 35     3   Dec  46956

# %%
plt.rcParams['figure.figsize'] = (20, 5)
data2['time']= data2["Month"]+ "-" + data2["Year"].map(str)

X = data2['time'].values
Y = data2['Units'].values

ticker = 'AMD'
timeframe = '1y'

plt.plot(X,Y)
plt.show()

# %%
rolling_mean = data1.High.rolling(window=10).mean()

plt.plot(rolling_mean, label='10 Day SMA', color='orange')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-4e48ce66998a> in <module>
# ----> 1 rolling_mean = data1.High.rolling(window=10).mean()
#       2
#       3 plt.plot(rolling_mean, label='10 Day SMA', color='orange')
#
# ~/.local/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'High'

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
dt=pd.read_csv("/home/dai/Downloads/RELIANCE.csv")
#print(dt)

dt=pd.read_csv("/home/dai/Downloads/RELIANCE.csv", header=None)
dt.columns=['Date','Open','High','Low','Last','Close','Volume','Turnover']
#dt.head()

dt=dt.tail(200)
#print(dt)
fig, ax = plt.subplots(figsize=(16,8))
print(ax)
plt.plot(dt['High'])
labels = ax.get_xticklabels()
print(labels)
plt.setp(labels, rotation=90, horizontalalignment='right')

plt.show()
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# <a list of 11 Text xticklabel objects>

# %%
# Out:
# 0

# %%
dt=pd.read_csv("/home/dai/Downloads/RELIANCE.csv")
#print(dt)

dt=pd.read_csv("/home/dai/Downloads/RELIANCE.csv", header=None)
dt.columns=['Date','Open','High','Low','Last','Close','Volume','Turnover']
#dt.head()
dt=dt.tail(200)
fig, ax = plt.subplots(figsize=(16,8))
plt.plot(dt['Last'])
plt.setp(labels, rotation=90, horizontalalignment='right')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,8))
rolling_mean = dt.High.rolling(window=10).mean()
rolling_mean2 = dt.High.rolling(window=50).mean()
plt.plot(dt['Last'])
plt.plot(rolling_mean, label='10 Day SMA', color='orange')

# %%
fig, ax = plt.subplots(figsize=(16,8))
rolling_mean = dt.High.rolling(window=10).mean()
rolling_mean2 = dt.High.rolling(window=50).mean()
plt.plot(dt['High'])
plt.plot(rolling_mean, label='10 Day SMA', color='orange')
plt.plot(rolling_mean2, label='50 Day SMA', color='magenta')
plt.legend(loc='upper left')
plt.show()
